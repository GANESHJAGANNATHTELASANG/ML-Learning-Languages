# %%
import pandas as pd

# %%
df = pd.read_csv("raw_data_02.csv")

# %%
df
# Out:
#     id          name   age country   gender   income
# 0    1      John Doe  29.0     USA     Male  55000.0
# 1    1      John Doe  29.0     USA     Male  55000.0
# 2    2    Jane Smith   NaN  Canada   Female  62000.0
# 3    3          Alex   NaN     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.0   Spain   Female      NaN
# 5    5        Li Wei  27.0   China     Male  51000.0
# 6    6           NaN  45.0   India   Female  73000.0
# 7    7    Ahmed Khan  38.0     NaN     Male  68000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 9    9   Carlos Ruiz   NaN  Mexico     Male  45000.0
# 10  10   Emily Davis  31.0     USA      NaN  58000.0

# %%
df2 = df

# %%
df2
# Out:
#     id          name   age country   gender   income
# 0    1      John Doe  29.0     USA     Male  55000.0
# 1    1      John Doe  29.0     USA     Male  55000.0
# 2    2    Jane Smith   NaN  Canada   Female  62000.0
# 3    3          Alex   NaN     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.0   Spain   Female      NaN
# 5    5        Li Wei  27.0   China     Male  51000.0
# 6    6           NaN  45.0   India   Female  73000.0
# 7    7    Ahmed Khan  38.0     NaN     Male  68000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 9    9   Carlos Ruiz   NaN  Mexico     Male  45000.0
# 10  10   Emily Davis  31.0     USA      NaN  58000.0

# %%
#future emngineering

# %%
df2["tax"]= df2["income"].apply(lambda x : "20%" if x <= 500000.0 else "50%")

# %%
df2
# Out:
#     id          name   age country gender   income  tax
# 0    1      John Doe  29.0     USA    NaN  55000.0  20%
# 1    1      John Doe  29.0     USA    NaN  55000.0  20%
# 2    2    Jane Smith   NaN  Canada    NaN  62000.0  20%
# 3    3          Alex   NaN     USA    NaN  47000.0  20%
# 4    4  Maria Garcia  34.0   Spain    NaN      NaN  50%
# 5    5        Li Wei  27.0   China    NaN  51000.0  20%
# 6    6           NaN  45.0   India    NaN  73000.0  20%
# 7    7    Ahmed Khan  38.0     NaN    NaN  68000.0  20%
# 8    8    Rachel Lee  29.0     USA    NaN  62000.0  20%
# 9    9   Carlos Ruiz   NaN  Mexico    NaN  45000.0  20%
# 10  10   Emily Davis  31.0     USA    NaN  58000.0  20%

# %%
gender = ({
    "Male" : "M",
    "Female" : "F",
    "Unknown" : "Chakka",
   
})
df2["gender"] = df2["gender"].map(gender)

# %%
df2
# Out:
#     id          name   age country gender   income  tax
# 0    1      John Doe  29.0     USA    NaN  55000.0  20%
# 1    1      John Doe  29.0     USA    NaN  55000.0  20%
# 2    2    Jane Smith   NaN  Canada    NaN  62000.0  20%
# 3    3          Alex   NaN     USA    NaN  47000.0  20%
# 4    4  Maria Garcia  34.0   Spain    NaN      NaN  50%
# 5    5        Li Wei  27.0   China    NaN  51000.0  20%
# 6    6           NaN  45.0   India    NaN  73000.0  20%
# 7    7    Ahmed Khan  38.0     NaN    NaN  68000.0  20%
# 8    8    Rachel Lee  29.0     USA    NaN  62000.0  20%
# 9    9   Carlos Ruiz   NaN  Mexico    NaN  45000.0  20%
# 10  10   Emily Davis  31.0     USA    NaN  58000.0  20%

# %%
dfe = df

# %%
gender = ({
    "Male" : "M",
    "Female" : "F",
    "Unknown" : "Chakka",
   
})

# %%
dfe["gender"] = dfe["gender"].map(gender)

# %%
dfe
# Out:
#     id          name   age country gender   income  tax gander
# 0    1      John Doe  29.0     USA    NaN  55000.0  20%    NaN
# 1    1      John Doe  29.0     USA    NaN  55000.0  20%    NaN
# 2    2    Jane Smith   NaN  Canada    NaN  62000.0  20%    NaN
# 3    3          Alex   NaN     USA    NaN  47000.0  20%    NaN
# 4    4  Maria Garcia  34.0   Spain    NaN      NaN  50%    NaN
# 5    5        Li Wei  27.0   China    NaN  51000.0  20%    NaN
# 6    6           NaN  45.0   India    NaN  73000.0  20%    NaN
# 7    7    Ahmed Khan  38.0     NaN    NaN  68000.0  20%    NaN
# 8    8    Rachel Lee  29.0     USA    NaN  62000.0  20%    NaN
# 9    9   Carlos Ruiz   NaN  Mexico    NaN  45000.0  20%    NaN
# 10  10   Emily Davis  31.0     USA    NaN  58000.0  20%    NaN

# %%
new = dfe.assign(taxeee = dfe["income"] + 10 )

# %%
new
# Out:
#     id          name   age country gender   income  tax gander   taxeee
# 0    1      John Doe  29.0     USA    NaN  55000.0  20%    NaN  55010.0
# 1    1      John Doe  29.0     USA    NaN  55000.0  20%    NaN  55010.0
# 2    2    Jane Smith   NaN  Canada    NaN  62000.0  20%    NaN  62010.0
# 3    3          Alex   NaN     USA    NaN  47000.0  20%    NaN  47010.0
# 4    4  Maria Garcia  34.0   Spain    NaN      NaN  50%    NaN      NaN
# 5    5        Li Wei  27.0   China    NaN  51000.0  20%    NaN  51010.0
# 6    6           NaN  45.0   India    NaN  73000.0  20%    NaN  73010.0
# 7    7    Ahmed Khan  38.0     NaN    NaN  68000.0  20%    NaN  68010.0
# 8    8    Rachel Lee  29.0     USA    NaN  62000.0  20%    NaN  62010.0
# 9    9   Carlos Ruiz   NaN  Mexico    NaN  45000.0  20%    NaN  45010.0
# 10  10   Emily Davis  31.0     USA    NaN  58000.0  20%    NaN  58010.0

# %%
dfe["country"] = dfe["country"].replace("USA", "VIJAYAPYR")

# %%
dfe
# Out:
#     id          name   age    country gender   income  tax gander
# 0    1      John Doe  29.0  VIJAYAPYR    NaN  55000.0  20%    NaN
# 1    1      John Doe  29.0  VIJAYAPYR    NaN  55000.0  20%    NaN
# 2    2    Jane Smith   NaN     Canada    NaN  62000.0  20%    NaN
# 3    3          Alex   NaN  VIJAYAPYR    NaN  47000.0  20%    NaN
# 4    4  Maria Garcia  34.0      Spain    NaN      NaN  50%    NaN
# 5    5        Li Wei  27.0      China    NaN  51000.0  20%    NaN
# 6    6           NaN  45.0      India    NaN  73000.0  20%    NaN
# 7    7    Ahmed Khan  38.0        NaN    NaN  68000.0  20%    NaN
# 8    8    Rachel Lee  29.0  VIJAYAPYR    NaN  62000.0  20%    NaN
# 9    9   Carlos Ruiz   NaN     Mexico    NaN  45000.0  20%    NaN
# 10  10   Emily Davis  31.0  VIJAYAPYR    NaN  58000.0  20%    NaN

# %%
dfe.columns = ["ID", "NAME", "AGE", "COUNTRY", "GENDER", "INCOME", "TAX", "GENDER"]

# %%
dfe
# Out:
#     ID          NAME   AGE    COUNTRY GENDER   INCOME  TAX GENDER
# 0    1      John Doe  29.0  VIJAYAPYR    NaN  55000.0  20%    NaN
# 1    1      John Doe  29.0  VIJAYAPYR    NaN  55000.0  20%    NaN
# 2    2    Jane Smith   NaN     Canada    NaN  62000.0  20%    NaN
# 3    3          Alex   NaN  VIJAYAPYR    NaN  47000.0  20%    NaN
# 4    4  Maria Garcia  34.0      Spain    NaN      NaN  50%    NaN
# 5    5        Li Wei  27.0      China    NaN  51000.0  20%    NaN
# 6    6           NaN  45.0      India    NaN  73000.0  20%    NaN
# 7    7    Ahmed Khan  38.0        NaN    NaN  68000.0  20%    NaN
# 8    8    Rachel Lee  29.0  VIJAYAPYR    NaN  62000.0  20%    NaN
# 9    9   Carlos Ruiz   NaN     Mexico    NaN  45000.0  20%    NaN
# 10  10   Emily Davis  31.0  VIJAYAPYR    NaN  58000.0  20%    NaN

# %%
dfe.rename(columns={"GENDER":"SEX"})
# Out:
#     ID          NAME   AGE    COUNTRY  SEX   INCOME  TAX  SEX
# 0    1      John Doe  29.0  VIJAYAPYR  NaN  55000.0  20%  NaN
# 1    1      John Doe  29.0  VIJAYAPYR  NaN  55000.0  20%  NaN
# 2    2    Jane Smith   NaN     Canada  NaN  62000.0  20%  NaN
# 3    3          Alex   NaN  VIJAYAPYR  NaN  47000.0  20%  NaN
# 4    4  Maria Garcia  34.0      Spain  NaN      NaN  50%  NaN
# 5    5        Li Wei  27.0      China  NaN  51000.0  20%  NaN
# 6    6           NaN  45.0      India  NaN  73000.0  20%  NaN
# 7    7    Ahmed Khan  38.0        NaN  NaN  68000.0  20%  NaN
# 8    8    Rachel Lee  29.0  VIJAYAPYR  NaN  62000.0  20%  NaN
# 9    9   Carlos Ruiz   NaN     Mexico  NaN  45000.0  20%  NaN
# 10  10   Emily Davis  31.0  VIJAYAPYR  NaN  58000.0  20%  NaN

# %%
dfe.rename(index={0:"FIRST_INDEX"})
# Out:
#              ID          NAME   AGE    COUNTRY GENDER   INCOME  TAX GENDER
# FIRST_INDEX   1      John Doe  29.0  VIJAYAPYR    NaN  55000.0  20%    NaN
# 1             1      John Doe  29.0  VIJAYAPYR    NaN  55000.0  20%    NaN
# 2             2    Jane Smith   NaN     Canada    NaN  62000.0  20%    NaN
# 3             3          Alex   NaN  VIJAYAPYR    NaN  47000.0  20%    NaN
# 4             4  Maria Garcia  34.0      Spain    NaN      NaN  50%    NaN
# 5             5        Li Wei  27.0      China    NaN  51000.0  20%    NaN
# 6             6           NaN  45.0      India    NaN  73000.0  20%    NaN
# 7             7    Ahmed Khan  38.0        NaN    NaN  68000.0  20%    NaN
# 8             8    Rachel Lee  29.0  VIJAYAPYR    NaN  62000.0  20%    NaN
# 9             9   Carlos Ruiz   NaN     Mexico    NaN  45000.0  20%    NaN
# 10           10   Emily Davis  31.0  VIJAYAPYR    NaN  58000.0  20%    NaN

# %%
dfe["INCOME"].sort_values()
# Out:
# 9     45000.0
# 3     47000.0
# 5     51000.0
# 0     55000.0
# 1     55000.0
# 10    58000.0
# 2     62000.0
# 8     62000.0
# 7     68000.0
# 6     73000.0
# 4         NaN
# Name: INCOME, dtype: float64

# %%
dfe.sort_values("INCOME")
# Out:
#     ID          NAME   AGE    COUNTRY GENDER   INCOME  TAX GENDER
# 9    9   Carlos Ruiz   NaN     Mexico    NaN  45000.0  20%    NaN
# 3    3          Alex   NaN  VIJAYAPYR    NaN  47000.0  20%    NaN
# 5    5        Li Wei  27.0      China    NaN  51000.0  20%    NaN
# 0    1      John Doe  29.0  VIJAYAPYR    NaN  55000.0  20%    NaN
# 1    1      John Doe  29.0  VIJAYAPYR    NaN  55000.0  20%    NaN
# 10  10   Emily Davis  31.0  VIJAYAPYR    NaN  58000.0  20%    NaN
# 2    2    Jane Smith   NaN     Canada    NaN  62000.0  20%    NaN
# 8    8    Rachel Lee  29.0  VIJAYAPYR    NaN  62000.0  20%    NaN
# 7    7    Ahmed Khan  38.0        NaN    NaN  68000.0  20%    NaN
# 6    6           NaN  45.0      India    NaN  73000.0  20%    NaN
# 4    4  Maria Garcia  34.0      Spain    NaN      NaN  50%    NaN

# %%
dfe.sort_values("INCOME", ascending=False) # descending
# Out:
#     ID          NAME   AGE    COUNTRY GENDER   INCOME  TAX GENDER
# 6    6           NaN  45.0      India    NaN  73000.0  20%    NaN
# 7    7    Ahmed Khan  38.0        NaN    NaN  68000.0  20%    NaN
# 2    2    Jane Smith   NaN     Canada    NaN  62000.0  20%    NaN
# 8    8    Rachel Lee  29.0  VIJAYAPYR    NaN  62000.0  20%    NaN
# 10  10   Emily Davis  31.0  VIJAYAPYR    NaN  58000.0  20%    NaN
# 0    1      John Doe  29.0  VIJAYAPYR    NaN  55000.0  20%    NaN
# 1    1      John Doe  29.0  VIJAYAPYR    NaN  55000.0  20%    NaN
# 5    5        Li Wei  27.0      China    NaN  51000.0  20%    NaN
# 3    3          Alex   NaN  VIJAYAPYR    NaN  47000.0  20%    NaN
# 9    9   Carlos Ruiz   NaN     Mexico    NaN  45000.0  20%    NaN
# 4    4  Maria Garcia  34.0      Spain    NaN      NaN  50%    NaN

# %%
sorted_data=dfe.sort_values(["INCOME", "AGE"]) # first check income if same income then age

# %%
sorted_data.sort_index()
# Out:
#     ID          NAME   AGE    COUNTRY GENDER   INCOME  TAX GENDER
# 0    1      John Doe  29.0  VIJAYAPYR    NaN  55000.0  20%    NaN
# 1    1      John Doe  29.0  VIJAYAPYR    NaN  55000.0  20%    NaN
# 2    2    Jane Smith   NaN     Canada    NaN  62000.0  20%    NaN
# 3    3          Alex   NaN  VIJAYAPYR    NaN  47000.0  20%    NaN
# 4    4  Maria Garcia  34.0      Spain    NaN      NaN  50%    NaN
# 5    5        Li Wei  27.0      China    NaN  51000.0  20%    NaN
# 6    6           NaN  45.0      India    NaN  73000.0  20%    NaN
# 7    7    Ahmed Khan  38.0        NaN    NaN  68000.0  20%    NaN
# 8    8    Rachel Lee  29.0  VIJAYAPYR    NaN  62000.0  20%    NaN
# 9    9   Carlos Ruiz   NaN     Mexico    NaN  45000.0  20%    NaN
# 10  10   Emily Davis  31.0  VIJAYAPYR    NaN  58000.0  20%    NaN

# %%
sorted_data["ranking"] = sorted_data["INCOME"].rank()

# %%
sorted_data
# Out:
#     ID          NAME   AGE    COUNTRY GENDER   INCOME  TAX GENDER  ranking
# 9    9   Carlos Ruiz   NaN     Mexico    NaN  45000.0  20%    NaN      1.0
# 3    3          Alex   NaN  VIJAYAPYR    NaN  47000.0  20%    NaN      2.0
# 5    5        Li Wei  27.0      China    NaN  51000.0  20%    NaN      3.0
# 0    1      John Doe  29.0  VIJAYAPYR    NaN  55000.0  20%    NaN      4.5
# 1    1      John Doe  29.0  VIJAYAPYR    NaN  55000.0  20%    NaN      4.5
# 10  10   Emily Davis  31.0  VIJAYAPYR    NaN  58000.0  20%    NaN      6.0
# 8    8    Rachel Lee  29.0  VIJAYAPYR    NaN  62000.0  20%    NaN      7.5
# 2    2    Jane Smith   NaN     Canada    NaN  62000.0  20%    NaN      7.5
# 7    7    Ahmed Khan  38.0        NaN    NaN  68000.0  20%    NaN      9.0
# 6    6           NaN  45.0      India    NaN  73000.0  20%    NaN     10.0
# 4    4  Maria Garcia  34.0      Spain    NaN      NaN  50%    NaN      NaN

# %%
dfe = dfe.reset_index(drop=True)

# %%
dfe
# Out:
#     ID          NAME   AGE    COUNTRY GENDER   INCOME  TAX GENDER
# 0    1      John Doe  29.0  VIJAYAPYR    NaN  55000.0  20%    NaN
# 1    1      John Doe  29.0  VIJAYAPYR    NaN  55000.0  20%    NaN
# 2    2    Jane Smith   NaN     Canada    NaN  62000.0  20%    NaN
# 3    3          Alex   NaN  VIJAYAPYR    NaN  47000.0  20%    NaN
# 4    4  Maria Garcia  34.0      Spain    NaN      NaN  50%    NaN
# 5    5        Li Wei  27.0      China    NaN  51000.0  20%    NaN
# 6    6           NaN  45.0      India    NaN  73000.0  20%    NaN
# 7    7    Ahmed Khan  38.0        NaN    NaN  68000.0  20%    NaN
# 8    8    Rachel Lee  29.0  VIJAYAPYR    NaN  62000.0  20%    NaN
# 9    9   Carlos Ruiz   NaN     Mexico    NaN  45000.0  20%    NaN
# 10  10   Emily Davis  31.0  VIJAYAPYR    NaN  58000.0  20%    NaN

# %%
dfe.to_csv("sorted.csv")# file creating

# %%
dfe.groupby("TAX")["INCOME"].min()
# Out:
# TAX
# 20%    45000.0
# 50%        NaN
# Name: INCOME, dtype: float64

# %%
dfe.groupby("COUNTRY")["INCOME"].mean()
# Out:
# COUNTRY
# Canada       62000.0
# China        51000.0
# India        73000.0
# Mexico       45000.0
# Spain            NaN
# VIJAYAPYR    55400.0
# Name: INCOME, dtype: float64

# %%
dfe.groupby("INCOME")["TAX"].max()
# Out:
# INCOME
# 45000.0    20%
# 47000.0    20%
# 51000.0    20%
# 55000.0    20%
# 58000.0    20%
# 62000.0    20%
# 68000.0    20%
# 73000.0    20%
# Name: TAX, dtype: object

# %%
dfe.groupby("COUNTRY")["INCOME"].agg(max_salary="max", min_salary="min", mean_salary="mean")
# Out:
#            max_salary  min_salary  mean_salary
# COUNTRY
# Canada        62000.0     62000.0      62000.0
# China         51000.0     51000.0      51000.0
# India         73000.0     73000.0      73000.0
# Mexico        45000.0     45000.0      45000.0
# Spain             NaN         NaN          NaN
# VIJAYAPYR     62000.0     47000.0      55400.0

# %%
dfe.groupby("COUNTRY")["INCOME"].agg(["max", "min","mean"])
# Out:
#                max      min     mean
# COUNTRY
# Canada     62000.0  62000.0  62000.0
# China      51000.0  51000.0  51000.0
# India      73000.0  73000.0  73000.0
# Mexico     45000.0  45000.0  45000.0
# Spain          NaN      NaN      NaN
# VIJAYAPYR  62000.0  47000.0  55400.0

# %%
dfe.groupby("COUNTRY").agg({
    "AGE": "max",
    "INCOME": "min"  
})
# Out:
#             AGE   INCOME
# COUNTRY
# Canada      NaN  62000.0
# China      27.0  51000.0
# India      45.0  73000.0
# Mexico      NaN  45000.0
# Spain      34.0      NaN
# VIJAYAPYR  31.0  47000.0

# %%
df1 = pd.DataFrame({
"id": [1, 2, 3],
"name": ["Adam", "Bob", "Charlie"]
})
df2 = pd.DataFrame({
"id": [4, 5, 6],
"name": ["David","Eva"
,
"Frank"]
})
pd.concat([df1, df2])
# Out:
#    id     name
# 0   1     Adam
# 1   2      Bob
# 2   3  Charlie
# 0   4    David
# 1   5      Eva
# 2   6    Frank

# %%
pd.concat([df1, df2], ignore_index=True)
# Out:
#    id     name
# 0   1     Adam
# 1   2      Bob
# 2   3  Charlie
# 3   4    David
# 4   5      Eva
# 5   6    Frank

# %%
df = pd.DataFrame({
"country": ["USA", "USA", "India", "India"],
"year": [2020, 2021, 2020, 2021],
"sales": [100, 120, 90, 110],
"profit": [20, 25, 18, 22]
})
melted = df.melt(
id_vars=["country", "year"], # columns to keep
value_vars=["sales", "profit"], # columns to unpivot
var_name="metric", # new column name for variable
value_name="value" # new column name for value (default is value)
)
print(melted)
# Out:
#   country  year  metric  value
# 0     USA  2020   sales    100
# 1     USA  2021   sales    120
# 2   India  2020   sales     90
# 3   India  2021   sales    110
# 4     USA  2020  profit     20
# 5     USA  2021  profit     25
# 6   India  2020  profit     18
# 7   India  2021  profit     22

# %%
df["sales"].hist()
# Out:
# <Axes: >

# %%
df.plot(kind="scatter", x="year", y="sales")
# Out:
# <Axes: xlabel='year', ylabel='sales'>

# %%
# Merging & Joining
df_customers = pd.DataFrame({
"customer_id": [1, 2, 3, 4],
"name": ["Adam", "Bob", "Charlie", "Dave"]
})
df_orders = pd.DataFrame({
"order_id": [101, 102, 103, 104],
"customer_id": [2, 1, 4, 5],
"amount": [250, 120, 300, 180]
})
pd.merge(df_customers, df_orders, on="customer_id") # Inner Join
# Out:
#    customer_id  name  order_id  amount
# 0            1  Adam       102     120
# 1            2   Bob       101     250
# 2            4  Dave       103     300

# %%
pd.merge(df_customers, df_orders, on="customer_id", how="left") # Left Join
# Out:
#    customer_id     name  order_id  amount
# 0            1     Adam     102.0   120.0
# 1            2      Bob     101.0   250.0
# 2            3  Charlie       NaN     NaN
# 3            4     Dave     103.0   300.0

# %%
pd.merge(df_customers, df_orders, on="customer_id", how="right") # Right Join
# Out:
#    customer_id  name  order_id  amount
# 0            2   Bob       101     250
# 1            1  Adam       102     120
# 2            4  Dave       103     300
# 3            5   NaN       104     180

# %%
pd.merge(df_customers, df_orders, on="customer_id", how="outer") #Outer Join
# Out:
#    customer_id     name  order_id  amount
# 0            1     Adam     102.0   120.0
# 1            2      Bob     101.0   250.0
# 2            3  Charlie       NaN     NaN
# 3            4     Dave     103.0   300.0
# 4            5      NaN     104.0   180.0
