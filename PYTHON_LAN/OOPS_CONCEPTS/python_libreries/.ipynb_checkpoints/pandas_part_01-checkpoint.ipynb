# %%
import pandas as pd

# %%
info = {
    "Nmae":["ganesh", "rachana", "sumit", "rakshit"],
    "CGPA":["22", "3","8", "7" ]
}

# %%
data = pd.DataFrame(info)

# %%
data
# Out:
#       Nmae CGPA
# 0   ganesh   22
# 1  rachana    3
# 2    sumit    8
# 3  rakshit    7

# %%
s = pd.Series([1,3,4,5,6,7])

# %%
s
# Out:
# 0    1
# 1    3
# 2    4
# 3    5
# 4    6
# 5    7
# dtype: int64

# %%
#index access
print(s[2])
print(s[5])
# Out:
# 4
# 7

# %%
f = pd.Series([1,3,4,5], index=["ganesh", "rachana", "sumit","raksh"])

# %%
f
# Out:
# ganesh     1
# rachana    3
# sumit      4
# raksh      5
# dtype: int64

# %%
#by label access
print(f["ganesh"])
print(f["rachana"])
print(f.index)
# Out:
# 1
# 3
# Index(['ganesh', 'rachana', 'sumit', 'raksh'], dtype='object')

# %%
s = pd.Series([1,3,4,5,6,7,3,4,4,5])
s = pd.Series([1,3,4,5,6,7,,3,4,4,5])
