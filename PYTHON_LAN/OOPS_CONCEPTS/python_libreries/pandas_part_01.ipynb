# %%
import pandas as pd

# %%
info = {
    "Nmae":["ganesh", "rachana", "sumit", "rakshit"],
    "CGPA":["22", "3","8", "7" ]
}

# %%
data = pd.DataFrame(info)

# %%
data
# Out:
#       Nmae CGPA
# 0   ganesh   22
# 1  rachana    3
# 2    sumit    8
# 3  rakshit    7

# %%
#Series

# %%
s = pd.Series([1,3,4,5,6,7])

# %%
s
# Out:
# 0    1
# 1    3
# 2    4
# 3    5
# 4    6
# 5    7
# dtype: int64

# %%
#index access
print(s[2])
print(s[5])
# Out:
# 4
# 7

# %%
f = pd.Series([1,3,4,5], index=["ganesh", "rachana", "sumit","raksh"])

# %%
f
# Out:
# ganesh     1
# rachana    3
# sumit      4
# raksh      5
# dtype: int64

# %%
#by label access
print(f["ganesh"])
print(f["rachana"])
print(f.index)
# Out:
# 1
# 3
# Index(['ganesh', 'rachana', 'sumit', 'raksh'], dtype='object')

# %%
g = pd.Series([1,3,4,5,6,7,3,4,4,5])
h = pd.Series([1,3,4,5,6,7,3,4,4,5])

print(g+h)
# Out:
# 0     2
# 1     6
# 2     8
# 3    10
# 4    12
# 5    14
# 6     6
# 7     8
# 8     8
# 9    10
# dtype: int64

# %%
changed = g.drop(0)

# %%
changed
# Out:
# 1    3
# 2    4
# 3    5
# 4    6
# 5    7
# 6    3
# 7    4
# 8    4
# 9    5
# dtype: int64

# %%
g
# Out:
# 0    1
# 1    3
# 2    4
# 3    5
# 4    6
# 5    7
# 6    3
# 7    4
# 8    4
# 9    5
# dtype: int64

# %%
#dataframes

# %%
inform = {
    "Nmae":["ganesh", "rachana", "sumit", "rakshit"],
    "CGPA":["22", "3","8", "7" ]
}

# %%
d = pd.DataFrame(inform)

# %%
d
# Out:
#       Nmae CGPA
# 0   ganesh   22
# 1  rachana    3
# 2    sumit    8
# 3  rakshit    7

# %%
print(d.index)
print(d.columns)
# Out:
# RangeIndex(start=0, stop=4, step=1)
# Index(['Nmae', 'CGPA'], dtype='object')

# %%
#list of list
da = pd.DataFrame([["ganesh", 99],["rachana", 99],["sumit", 99],["raksh", 99]], columns=["Name", "Percentage"])

# %%
da
# Out:
#       Name  Percentage
# 0   ganesh          99
# 1  rachana          99
# 2    sumit          99
# 3    raksh          99

# %%
#csv

# %%
df = pd.read_csv("raw_data_02.csv")

# %%
df
# Out:
#     id          name   age country   gender   income
# 0    1      John Doe  29.0     USA     Male  55000.0
# 1    1      John Doe  29.0     USA     Male  55000.0
# 2    2    Jane Smith   NaN  Canada   Female  62000.0
# 3    3          Alex   NaN     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.0   Spain   Female      NaN
# 5    5        Li Wei  27.0   China     Male  51000.0
# 6    6           NaN  45.0   India   Female  73000.0
# 7    7    Ahmed Khan  38.0     NaN     Male  68000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 9    9   Carlos Ruiz   NaN  Mexico     Male  45000.0
# 10  10   Emily Davis  31.0     USA      NaN  58000.0

# %%
df = pd.read_json("data.json")

# %%
df
# Out:
#    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000
# 3   4    David   45  Marketing   91000
# 4   5      Eva   38         IT   65000
# 5   6    Frank   29    Finance   50000
# 6   7    Grace   41         HR   82000
# 7   8   Hannah   26  Marketing   47000
# 8   9      Ian   35         IT   75000
# 9  10    Julia   30    Finance   60000

# %%
df = pd.read_csv("globalAirQuality.csv")

# %%
df
# Out:
#                         timestamp country      city  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 1      2025-11-04 19:25:17.554219      US  New York    40.713    -74.006
# 2      2025-11-04 20:25:17.554219      US  New York    40.713    -74.006
# 3      2025-11-04 21:25:17.554219      US  New York    40.713    -74.006
# 4      2025-11-04 22:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17995  2025-11-19 13:25:17.554219      CH    Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH    Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH    Zurich    47.377      8.542
# 17998  2025-11-19 16:25:17.554219      CH    Zurich    47.377      8.542
# 17999  2025-11-19 17:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
df.head()
# Out:
#                     timestamp country      city  latitude  longitude    pm25  \
# 0  2025-11-04 18:25:17.554219      US  New York    40.713    -74.006  50.295
# 1  2025-11-04 19:25:17.554219      US  New York    40.713    -74.006  32.083
# 2  2025-11-04 20:25:17.554219      US  New York    40.713    -74.006  42.250
# 3  2025-11-04 21:25:17.554219      US  New York    40.713    -74.006  30.403
# 4  2025-11-04 22:25:17.554219      US  New York    40.713    -74.006  21.083
#
#       pm10     no2    so2      o3     co  aqi  temperature  humidity  \
# 0  108.938  27.998  6.539  52.568  1.096  108       18.504    70.168
# 1   63.043  36.120  4.021  43.536  1.075   90        5.838    80.088
# 2   82.553  26.935  9.538  23.320  0.977   84       31.833    62.783
# 3   79.951  63.536  7.609  31.369  0.230  158       23.140    89.153
# 4   66.423  38.997  6.919  45.615  1.085   97       13.632    76.499
#
#    wind_speed
# 0       3.725
# 1       8.969
# 2       9.650
# 3       8.956
# ...

# %%
df.tail()
# Out:
#                         timestamp country    city  latitude  longitude  \
# 17995  2025-11-19 13:25:17.554219      CH  Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH  Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH  Zurich    47.377      8.542
# 17998  2025-11-19 16:25:17.554219      CH  Zurich    47.377      8.542
# 17999  2025-11-19 17:25:17.554219      CH  Zurich    47.377      8.542
#
#          pm25    pm10     no2    so2      o3     co  aqi  temperature  \
# 17995  27.899  74.179  41.474  6.677  50.869  1.028  103        7.079
# 17996   2.950  47.988  42.235  2.821  35.551  0.644  105       28.734
# 17997  61.347  72.908  46.976  5.763  66.492  0.947  122       21.951
# 17998  40.722  95.152  32.957  5.524  53.193  0.868   95       24.042
# 17999  25.830  30.411  35.317  4.336  66.246  0.848   88        8.529
#
#        humidity  wind_speed
# 17995    52.443       7.452
# 17996    85.678       4.496
# 17997    72.311       9.660
# ...

# %%
df.describe()
# Out:
#            latitude     longitude          pm25          pm10           no2  \
# count  18000.000000  18000.000000  18000.000000  18000.000000  18000.000000
# mean      23.065980     37.655560     40.369131     70.152228     32.055176
# std       26.156536     78.600701     17.647450     24.999440     13.820680
# min      -37.814000   -123.121000      0.025000      0.061000      0.013000
# 25%       12.972000      2.352000     27.904500     53.125500     22.362500
# 50%       29.232000     42.146000     40.286500     69.961000     32.019500
# 75%       41.008000    103.820000     52.436250     87.256500     41.364250
# max       60.170000    174.763000    115.683000    161.810000     90.019000
#
#                 so2            o3            co           aqi   temperature  \
# count  18000.000000  18000.000000  18000.000000  18000.000000  18000.000000
# mean       6.035508     48.065100      0.800595    104.645556     21.510251
# ...

# %%
#colunms

# %%
df["country"]
# Out:
# 0        US
# 1        US
# 2        US
# 3        US
# 4        US
#          ..
# 17995    CH
# 17996    CH
# 17997    CH
# 17998    CH
# 17999    CH
# Name: country, Length: 18000, dtype: object

# %%
df[["country", "longitude"]]
# Out:
#       country  longitude
# 0          US    -74.006
# 1          US    -74.006
# 2          US    -74.006
# 3          US    -74.006
# 4          US    -74.006
# ...       ...        ...
# 17995      CH      8.542
# 17996      CH      8.542
# 17997      CH      8.542
# 17998      CH      8.542
# 17999      CH      8.542
#
# [18000 rows x 2 columns]

# %%
# row by loc

# %%
df.loc[0] # get the colomns by name not insdex
# Out:
# timestamp      2025-11-04 18:25:17.554219
# country                                US
# city                             New York
# latitude                           40.713
# longitude                         -74.006
# pm25                               50.295
# pm10                              108.938
# no2                                27.998
# so2                                 6.539
# o3                                 52.568
# co                                  1.096
# aqi                                   108
# temperature                        18.504
# humidity                           70.168
# wind_speed                          3.725
# Name: 0, dtype: object

# %%
df.loc[0:2] #here the last 2 also inclused it is inclusive,  get the colomns by index not name
# Out:
#                     timestamp country      city  latitude  longitude    pm25  \
# 0  2025-11-04 18:25:17.554219      US  New York    40.713    -74.006  50.295
# 1  2025-11-04 19:25:17.554219      US  New York    40.713    -74.006  32.083
# 2  2025-11-04 20:25:17.554219      US  New York    40.713    -74.006  42.250
#
#       pm10     no2    so2      o3     co  aqi  temperature  humidity  \
# 0  108.938  27.998  6.539  52.568  1.096  108       18.504    70.168
# 1   63.043  36.120  4.021  43.536  1.075   90        5.838    80.088
# 2   82.553  26.935  9.538  23.320  0.977   84       31.833    62.783
#
#    wind_speed
# 0       3.725
# 1       8.969
# 2       9.650

# %%
df.iloc[0:2] # here it is exclusive
# Out:
#                     timestamp country      city  latitude  longitude    pm25  \
# 0  2025-11-04 18:25:17.554219      US  New York    40.713    -74.006  50.295
# 1  2025-11-04 19:25:17.554219      US  New York    40.713    -74.006  32.083
#
#       pm10     no2    so2      o3     co  aqi  temperature  humidity  \
# 0  108.938  27.998  6.539  52.568  1.096  108       18.504    70.168
# 1   63.043  36.120  4.021  43.536  1.075   90        5.838    80.088
#
#    wind_speed
# 0       3.725
# 1       8.969

# %%
df.loc[0:2, ["country", "latitude", "temperature" ]]
# Out:
#   country  latitude  temperature
# 0      US    40.713       18.504
# 1      US    40.713        5.838
# 2      US    40.713       31.833

# %%
df.iloc[0:2, ["country", "latitude", "temperature" ]]  
#this will give error bcz we can't access ny the name we want to access by index
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 df.iloc[0:2, ["country", "latitude", "temperature" ]]
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/indexing.py:1185, in _LocationIndexer.__getitem__(self, key)
#    1183     if self._is_scalar_access(key):
#    1184         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1185     return self._getitem_tuple(key)
#    1186 else:
#    1187     # we by definition only have the 0th axis
#    1188     axis = self.axis or 0
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/indexing.py:1691, in _iLocIndexer._getitem_tuple(self, tup)
#    1690 def _getitem_tuple(self, tup: tuple):
# -> 1691     tup = self._validate_tuple_indexer(tup)
#    1692     with suppress(IndexingError):
#    1693         return self._getitem_lowerdim(tup)
#
# ...

# %%
df.iloc[0:2, 1:5]
# Out:
#   country      city  latitude  longitude
# 0      US  New York    40.713    -74.006
# 1      US  New York    40.713    -74.006

# %%
# see if we change anything in df it will change in original so better pracctice to do .copy() if u are changing

# %%
daa = df["country"].copy()

# %%
daa
# Out:
# 0        US
# 1        US
# 2        US
# 3        US
# 4        US
#          ..
# 17995    CH
# 17996    CH
# 17997    CH
# 17998    CH
# 17999    CH
# Name: country, Length: 18000, dtype: object

# %%
daa[0] = "vijayapur"

# %%
daa # see it is chnaged, for this reason we want to store an copy of that
# Out:
# 0        vijayapur
# 1               US
# 2               US
# 3               US
# 4               US
#            ...
# 17995           CH
# 17996           CH
# 17997           CH
# 17998           CH
# 17999           CH
# Name: country, Length: 18000, dtype: object

# %%
#filetring of data

# %%
df[df["pm10"] > 108.938]
# Out:
#                         timestamp country      city  latitude  longitude  \
# 7      2025-11-05 01:25:17.554219      US  New York    40.713    -74.006
# 14     2025-11-05 08:25:17.554219      US  New York    40.713    -74.006
# 29     2025-11-05 23:25:17.554219      US  New York    40.713    -74.006
# 31     2025-11-06 01:25:17.554219      US  New York    40.713    -74.006
# 38     2025-11-06 08:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17926  2025-11-16 16:25:17.554219      CH    Zurich    47.377      8.542
# 17945  2025-11-17 11:25:17.554219      CH    Zurich    47.377      8.542
# 17963  2025-11-18 05:25:17.554219      CH    Zurich    47.377      8.542
# 17968  2025-11-18 10:25:17.554219      CH    Zurich    47.377      8.542
# 17978  2025-11-18 20:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
df[(df["pm10"] > 108.938) & (df["city"] == "New York") ]
# Out:
#                       timestamp country      city  latitude  longitude  \
# 7    2025-11-05 01:25:17.554219      US  New York    40.713    -74.006
# 14   2025-11-05 08:25:17.554219      US  New York    40.713    -74.006
# 29   2025-11-05 23:25:17.554219      US  New York    40.713    -74.006
# 31   2025-11-06 01:25:17.554219      US  New York    40.713    -74.006
# 38   2025-11-06 08:25:17.554219      US  New York    40.713    -74.006
# 44   2025-11-06 14:25:17.554219      US  New York    40.713    -74.006
# 47   2025-11-06 17:25:17.554219      US  New York    40.713    -74.006
# 64   2025-11-07 10:25:17.554219      US  New York    40.713    -74.006
# 77   2025-11-07 23:25:17.554219      US  New York    40.713    -74.006
# 83   2025-11-08 05:25:17.554219      US  New York    40.713    -74.006
# 103  2025-11-09 01:25:17.554219      US  New York    40.713    -74.006
# 113  2025-11-09 11:25:17.554219      US  New York    40.713    -74.006
# ...

# %%
df[(df["pm10"] > 108.938) | (df["city"] == "New York") ]
# Out:
#                         timestamp country      city  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 1      2025-11-04 19:25:17.554219      US  New York    40.713    -74.006
# 2      2025-11-04 20:25:17.554219      US  New York    40.713    -74.006
# 3      2025-11-04 21:25:17.554219      US  New York    40.713    -74.006
# 4      2025-11-04 22:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17926  2025-11-16 16:25:17.554219      CH    Zurich    47.377      8.542
# 17945  2025-11-17 11:25:17.554219      CH    Zurich    47.377      8.542
# 17963  2025-11-18 05:25:17.554219      CH    Zurich    47.377      8.542
# 17968  2025-11-18 10:25:17.554219      CH    Zurich    47.377      8.542
# 17978  2025-11-18 20:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
df[(df["pm10"] > 108.938) & (df["city"] == "New York")][["city", "country"]]
# Out:
#          city country
# 7    New York      US
# 14   New York      US
# 29   New York      US
# 31   New York      US
# 38   New York      US
# 44   New York      US
# 47   New York      US
# 64   New York      US
# 77   New York      US
# 83   New York      US
# 103  New York      US
# 113  New York      US
# 114  New York      US
# 122  New York      US
# 158  New York      US
# 193  New York      US
# 203  New York      US
# 204  New York      US
# 209  New York      US
# 225  New York      US
# 229  New York      US
# 239  New York      US
# 240  New York      US
# 268  New York      US
# 273  New York      US
# 323  New York      US
# 335  New York      US

# %%
#query

# %%
df.query("pm10 > 100 ")
# Out:
#                         timestamp country      city  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 7      2025-11-05 01:25:17.554219      US  New York    40.713    -74.006
# 14     2025-11-05 08:25:17.554219      US  New York    40.713    -74.006
# 20     2025-11-05 14:25:17.554219      US  New York    40.713    -74.006
# 29     2025-11-05 23:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17933  2025-11-16 23:25:17.554219      CH    Zurich    47.377      8.542
# 17945  2025-11-17 11:25:17.554219      CH    Zurich    47.377      8.542
# 17963  2025-11-18 05:25:17.554219      CH    Zurich    47.377      8.542
# 17968  2025-11-18 10:25:17.554219      CH    Zurich    47.377      8.542
# 17978  2025-11-18 20:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
#cleaning of data

# %%
data = pd.read_csv("raw_data_02.csv")

# %%
data
# Out:
#     id          name   age country   gender   income
# 0    1      John Doe  29.0     USA     Male  55000.0
# 1    1      John Doe  29.0     USA     Male  55000.0
# 2    2    Jane Smith   NaN  Canada   Female  62000.0
# 3    3          Alex   NaN     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.0   Spain   Female      NaN
# 5    5        Li Wei  27.0   China     Male  51000.0
# 6    6           NaN  45.0   India   Female  73000.0
# 7    7    Ahmed Khan  38.0     NaN     Male  68000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 9    9   Carlos Ruiz   NaN  Mexico     Male  45000.0
# 10  10   Emily Davis  31.0     USA      NaN  58000.0

# %%
data.isnull()  # or data.isna()    this also gove the same thing
# Out:
#        id   name    age  country  gender  income
# 0   False  False  False    False   False   False
# 1   False  False  False    False   False   False
# 2   False  False   True    False   False   False
# 3   False  False   True    False   False   False
# 4   False  False  False    False   False    True
# 5   False  False  False    False   False   False
# 6   False   True  False    False   False   False
# 7   False  False  False     True   False   False
# 8   False  False  False    False   False   False
# 9   False  False   True    False   False   False
# 10  False  False  False    False    True   False

# %%
#using chainn 
data.isna().sum()
# Out:
# id         0
# name       1
# age        3
# country    1
# gender     1
# income     1
# dtype: int64

# %%
drop_data = data.dropna()

# %%
drop_data
# Out:
#    id        name   age country  gender   income
# 0   1    John Doe  29.0     USA    Male  55000.0
# 1   1    John Doe  29.0     USA    Male  55000.0
# 5   5      Li Wei  27.0   China    Male  51000.0
# 8   8  Rachel Lee  29.0     USA  Female  62000.0

# %%
fill_data = data.fillna(0)

# %%
fill_data
# Out:
#     id          name   age country   gender   income
# 0    1      John Doe  29.0     USA     Male  55000.0
# 1    1      John Doe  29.0     USA     Male  55000.0
# 2    2    Jane Smith   0.0  Canada   Female  62000.0
# 3    3          Alex   0.0     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.0   Spain   Female      0.0
# 5    5        Li Wei  27.0   China     Male  51000.0
# 6    6             0  45.0   India   Female  73000.0
# 7    7    Ahmed Khan  38.0       0     Male  68000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 9    9   Carlos Ruiz   0.0  Mexico     Male  45000.0
# 10  10   Emily Davis  31.0     USA        0  58000.0

# %%
clean_data = data.copy()
age_mean = clean_data["age"].mean()
clean_data["age"]=clean_data["age"].fillna(age_mean)

# %%
clean_data
# Out:
#     id          name    age country   gender   income
# 0    1      John Doe  29.00     USA     Male  55000.0
# 1    1      John Doe  29.00     USA     Male  55000.0
# 2    2    Jane Smith  32.75  Canada   Female  62000.0
# 3    3          Alex  32.75     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.00   Spain   Female      NaN
# 5    5        Li Wei  27.00   China     Male  51000.0
# 6    6           NaN  45.00   India   Female  73000.0
# 7    7    Ahmed Khan  38.00     NaN     Male  68000.0
# 8    8    Rachel Lee  29.00     USA   Female  62000.0
# 9    9   Carlos Ruiz  32.75  Mexico     Male  45000.0
# 10  10   Emily Davis  31.00     USA      NaN  58000.0

# %%
data["age"].ffill()
# Out:
# 0     29.0
# 1     29.0
# 2     29.0
# 3     29.0
# 4     34.0
# 5     27.0
# 6     45.0
# 7     38.0
# 8     29.0
# 9     29.0
# 10    31.0
# Name: age, dtype: float64

# %%
data["age"].bfill()
# Out:
# 0     29.0
# 1     29.0
# 2     34.0
# 3     34.0
# 4     34.0
# 5     27.0
# 6     45.0
# 7     38.0
# 8     29.0
# 9     31.0
# 10    31.0
# Name: age, dtype: float64

# %%
#Hanmdle dublicate

# %%
data.duplicated()
# Out:
# 0     False
# 1      True
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# dtype: bool

# %%
data["gender"].duplicated()
# Out:
# 0     False
# 1      True
# 2     False
# 3     False
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10    False
# Name: gender, dtype: bool

# %%
data[["gender", "country"]].duplicated()
# Out:
# 0     False
# 1      True
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# dtype: bool

# %%
data.drop_duplicates()
# Out:
#     id          name   age country   gender   income
# 0    1      John Doe  29.0     USA     Male  55000.0
# 2    2    Jane Smith   NaN  Canada   Female  62000.0
# 3    3          Alex   NaN     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.0   Spain   Female      NaN
# 5    5        Li Wei  27.0   China     Male  51000.0
# 6    6           NaN  45.0   India   Female  73000.0
# 7    7    Ahmed Khan  38.0     NaN     Male  68000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 9    9   Carlos Ruiz   NaN  Mexico     Male  45000.0
# 10  10   Emily Davis  31.0     USA      NaN  58000.0

# %%
#handle string

# %%
# Handle Data Types

df = 

df.dtypes                                     # dtype of each col
df2 = df.fillna(0).copy()
df2["age"] = df2["age"].astype(int)       # change dtype

# String type
df2["gender"].str.lower()                      # lower case
df2["gender"].str.upper()                      # upper case
df2["gender"].str.capitalize()                 # capitalize

df2["gender"].str.capitalize()                 # capitalize
df2["name"].str.split(" ")                     # splits into lists based on separator value 
type(df2["name"].str.split(" ")[0])            

df2["country"].str.contains("US")
df2["country"].str.contains("india", case=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[58], line 5
# ...
