# %%
import pandas as pd

# %%
data = {
    "name":["ganesh", "vijay", "setupati", "rohan", "rahul"],
    "marks":[10, 50, 66, 40, 97 ],
    "stu":[1, 5, 6, 4, 9]

}

# %%
da = {
    "st":[2,6,3,9,4]

}

# %%
df = pd.DataFrame(data)

# %%
dfe = pd.DataFrame(da)

# %%
print(dfe)
# Out:
#    st
# 0   2
# 1   6
# 2   3
# 3   9
# 4   4

# %%
X = df[["marks"]] 
y = df[["stu"]]
x = df[["st"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 3
#       1 X = df[["marks"]]
#       2 y = df[["stu"]]
# ----> 3 x = df[["st"]]
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/indexes/base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
# ...

# %%
from sklearn.linear_model import LinearRegression 
model = LinearRegression()
model.fit(y, X)

y_pre = model.predict(x)
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 5
#       2 model = LinearRegression()
#       3 model.fit(y, X)
# ----> 5 y_pre = model.predict(x)
#
# File /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_base.py:298, in LinearModel.predict(self, X)
#     284 def predict(self, X):
#     285     """
#     286     Predict using the linear model.
#     287
#    (...)    296         Returns predicted values.
#     297     """
# --> 298     return self._decision_function(X)
#
# File /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_base.py:277, in LinearModel._decision_function(self, X)
#     274 def _decision_function(self, X):
# ...

# %%
y_pre
# Out:
# array([[1.14339659],
#        [4.76462045],
#        [6.21310999],
#        [3.85931448],
#        [9.01955848]])
